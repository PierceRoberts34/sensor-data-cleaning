# %%
from main import probabilitySignal, promptLLM
from IPython.display import Image

# %%
markovPath = probabilitySignal('markov_prob', 0.01)
Image(filename=markovPath)
# Out:
# Generating a single combined plot for the last 30 periods...

# %%
iforestPath = probabilitySignal('iforest_score', -0.15)
Image(filename=iforestPath)
# Out:
# Generating a single combined plot for the last 30 periods...

# %%
promptLLM(markovPath)
# Out:
# Feeding combined image to local llm...
#
# === LLM Analysis ===
# The graph corresponding to **2026-02-08** appears significantly different in both **shape** and **number of anomalies** compared to other graphs. Specifically:
#
# - **Shape**: The red points (low probability indicators) are concentrated in the middle of the day (12:00–18:00), forming a distinct cluster pattern. This contrasts with the other graphs, which show scattered or more uniform red points across the day.
# - **Number of anomalies**: This graph has a notably higher number of red points (anomalies) than most others, with a density that is statistically significant (e.g., 30–40 anomalies in comparison to an average of 10–20). This elevated anomaly count, while not extreme, is disproportionately high compared to the remaining graphs, making it a clear outlier.
#
# Thus, **2026-02-08** stands out as the graph with the most significant deviation in both form and magnitude of anomalies.
# ====================
# Review complete in 26.72 seconds

# %%
promptLLM(iforestPath)
# Out:
# Feeding combined image to local llm...
#
# === LLM Analysis ===
# The graph for **2026-02-11** is significantly different from the other graphs. This graph has a notably higher number of red points compared to the others, indicating a distinct pattern of anomalies or outliers. Specifically, it exhibits a concentrated distribution of red points, which is not typical of the other graphs that show more scattered or less dense red point distributions. This difference in pattern and density makes it stand out as significantly different from the remaining graphs.
# ====================
# Review complete in 29.20 seconds
